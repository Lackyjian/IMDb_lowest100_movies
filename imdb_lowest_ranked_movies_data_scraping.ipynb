# %% [markdown]
# # IMPORTING REQUIRED LIBRARIES

# %%
from selenium import webdriver                          #For opening browser       
import pandas as pd                                     #For creating dataframe
from bs4 import BeautifulSoup                           #For scraping data
import time                                             #For waiting
import numpy as np                                      #For array
from tqdm import tqdm                                   #For progress bar

# %% [markdown]
# # OPENING REQUIRED SITE IN BROWSER

# %%
driver = webdriver.Firefox()

# %%
driver.get('https://www.imdb.com/chart/bottom/')

# %% [markdown]
# # GETTING HTML CODE OF OPENED WEBPAGE

# %%
html = driver.page_source

# %% [markdown]
# # CONVERTING EXTRACTED HTML CODE INTO SOUP TO SCRAP DATA

# %%
soup = BeautifulSoup(html,"html.parser")

# %% [markdown]
# # EXTRACTING LINKS TO THE INDIVIDUAL WEBPAGES OF MOVIES

# %%
link_list = [soup.findAll('li', {'class':'ipc-metadata-list-summary-item sc-59b6048d-0 cuaJSp cli-parent'})[i].findAll('a')[0].get('href') for i in range(100)]

# %% [markdown]
# # FUNCTION TO EXTRACT NAME OF THE MOVIE

# %%
def get_name(soup):
    basic_info = soup.findAll('div',{'class':'sc-dffc6c81-0 grcyBP'})[0]
    return basic_info.findAll('span')[0].text

# %% [markdown]
# # FUNCTION TO EXTRACT RELEASE YEAR OF THE MOVIE

# %%
def get_year(soup):
    try:
        basic_info = soup.findAll('div',{'class':'sc-dffc6c81-0 grcyBP'})[0]
        return basic_info.findAll('a')[0].text
    except Exception as e:
        return np.nan

# %% [markdown]
# # FUNCTION TO EXTRACT CERTIFICATION RATE OF THE MOVIE

# %%
def get_rate(soup):
    try:
        basic_info = soup.findAll('div',{'class':'sc-dffc6c81-0 grcyBP'})[0]
        return basic_info.findAll('a')[1].text
    except Exception as e:
        return np.nan

# %% [markdown]
# # FUNCTION TO EXTRACT DURATION OF THE MOVIE

# %%
def get_duration(soup):
    try:
        basic_info = soup.findAll('div',{'class':'sc-dffc6c81-0 grcyBP'})[0]
        return basic_info.findAll('li', {'class':'ipc-inline-list__item'})[2].text
    except Exception as e:
        return np.nan

# %% [markdown]
# # FUNCTION TO EXTRACT RATING OF THE MOVIE

# %%
def get_rating(soup):
    try:
        return soup.findAll('span', {'class':'sc-bde20123-1 cMEQkK'})[0].text
    except Exception as e:
        return np.nan

# %% [markdown]
# # FUNCTION TO EXTRACT NUMBER OF USERS OF THE MOVIE

# %%
def get_users(soup):
    try:
        return soup.findAll('div', {'class':'sc-bde20123-3 gPVQxL'})[0].text
    except Exception as e:
        return np.nan

# %% [markdown]
# # FUNCTION TO EXTRACT DIRECTOR NAME OF THE MOVIE

# %%
def get_director(soup):
    try:
        dir_data = soup.findAll('li', {'class':'ipc-metadata-list__item'})[0].findAll('a')
        dir_list = [dir.text for dir in dir_data]
        return dir_list
    except Exception as e:
        return np.nan

# %% [markdown]
# # FUNCTION TO EXTRACT WRITER NAME OF THE MOVIE

# %%
def get_writer(soup):
    try:
        wrt_data = soup.findAll('li', {'class':'ipc-metadata-list__item'})[1].findAll('a')
        wrt_list = [wrt.text for wrt in wrt_data]
        return wrt_list
    except Exception as e:
        return np.nan

# %% [markdown]
# # FUNCTION TO EXTRACT GENRE OF THE MOVIE

# %%
def get_genre(soup):
    try:
        genre_data = soup.findAll('div', {'class':'ipc-chip-list__scroller'})[0].findAll('a')
        genre_list = [genre.text for genre in genre_data]
        return genre_list
    except Exception as e:
        return np.nan

# %% [markdown]
# # FUNCTION TO EXTRACT STARS OF THE MOVIE

# %%
def get_stars(soup):
    try:
        star_data = soup.findAll('div', {'class':'ipc-metadata-list-item__content-container'})[2].findAll('a')
        star_list = [star.text for star in star_data]
        return star_list
    except Exception as e:
        return np.nan

# %% [markdown]
# # MAIN LOOP TO ITERATE THROUGH EACH MOVIE'S WEBPAGE AND EXTRACT DATA

# %%
name = []
year = []
rate = []
duration = []
rating = []
reviews = []
dir = []
writers = []
genre = []
stars = []
for link in tqdm(link_list):
    driver.get(f'https://www.imdb.com{link}')
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    name.append(get_name(soup))
    year.append(get_year(soup))
    rate.append(get_rate(soup))
    duration.append(get_duration(soup))
    rating.append(get_rating(soup))
    reviews.append(get_users(soup))
    dir.append(get_director(soup))
    writers.append(get_writer(soup))
    genre.append(get_genre(soup))
    stars.append(get_stars(soup))
# Out:
# 100%|██████████| 100/100 [11:26<00:00,  6.86s/it]

# %% [markdown]
# # CREATING DATAFRAME FOR COLLECTED DATASET

# %%
df = pd.DataFrame({
    'rank':np.arange(1,101),
    'name':name,
    'year':year,
    'certification':rate,
    'duration':duration,
    'rating':rating,
    'review_count':reviews,
    'director':dir,
    'writer':writers,
    'genre':genre,
    'stars':stars
})

# %% [markdown]
# # CHECKING THE DATASET

# %%
df.head()
# Out:
#    rank                          name  year certification duration rating  \
# 0     1                Disaster Movie  2008         PG-13   1h 27m    1.9
# 1     2      Manos: The Hands of Fate  1966     Not Rated   1h 10m    1.6
# 2     3    Birdemic: Shock and Terror  2010     Not Rated   1h 45m    1.7
# 3     4  Superbabies: Baby Geniuses 2  2004            PG   1h 28m    1.5
# 4     5       The Hottie & the Nottie  2008         PG-13   1h 31m    2.0
#
#   review_count                          director  \
# 0          94K  [Jason Friedberg, Aaron Seltzer]
# 1          37K                [Harold P. Warren]
# 2          25K                    [James Nguyen]
# 3          32K                       [Bob Clark]
# 4          39K                      [Tom Putnam]
#
#                                               writer  \
# 0                   [Jason Friedberg, Aaron Seltzer]
# 1                                 [Harold P. Warren]
# 2                           [Writer, James Nguyen, ]
# 3  [Writers, Robert Grasmere, Francisca Matos, St...
# 4                                     [Heidi Ferrer]
#
#                       genre                                              stars
# 0          [Comedy, Sci-Fi]    [Carmen Electra, Vanessa Lachey, Nicole Parker]
# 1                  [Horror]         [Tom Neyman, John Reynolds, Diane Adelson]
# 2        [Horror, Thriller]           [Alan Bagh, Whitney Moore, Tippi Hedren]
# 3  [Comedy, Family, Sci-Fi]            [Jon Voight, Scott Baio, Vanessa Angel]
# 4         [Comedy, Romance]  [Paris Hilton, Joel David Moore, Christine Lakin]

# %%
df.sample(20)
# Out:
#     rank                                       name  year certification  \
# 62    63                     The Master of Disguise  2002            PG
# 10    11                          Battlefield Earth  2000         PG-13
# 21    22                                 Date Movie  2006         PG-13
# 28    29                          Jaws: The Revenge  1987         PG-13
# 78    79                  The NeverEnding Story III  1994             G
# 2      3                 Birdemic: Shock and Terror  2010     Not Rated
# 14      [Action, Crime, Thriller]
# 88    [Horror, Mystery, Thriller]
# 95       [Comedy, Romance, Sport]
# 61                        [Drama]
# 13   [Action, Adventure, Fantasy]
# 91        [Drama, Romance, Sport]
# 90                       [Comedy]
# 5                [Comedy, Family]
# 45    [Horror, Mystery, Thriller]
# 51     [Action, Adventure, Crime]
# 67    [Action, Adventure, Sci-Fi]
#
#                                                 stars
# 62     [Dana Carvey, Jennifer Esposito, Harold Gould]
# 10     [John Travolta, Forest Whitaker, Barry Pepper]
# 21     [Alyson Hannigan, Adam Campbell, Fred Willard]
# 28    [Lorraine Gary, Lance Guest, Mario Van Peebles]
# 78      [Jason James Richter, Melody Kay, Jack Black]
# 2            [Alan Bagh, Whitney Moore, Tippi Hedren]
# 72            [Loni Anderson, Hulk Hogan, Jim Varney]
# 84      [Imogen Poots, Aleyse Shannon, Lily Donoghue]
# 55      [Cody Kearsley, Bruce Willis, Rachel Nichols]
# 14             [Anil Kapoor, Salman Khan, Bobby Deol]
# 88      [Brooke Nevin, David Paetkau, Torrey DeVitto]
# 95           [Mike Myers, Jessica Alba, Romany Malco]
# 61    [Tommy Wiseau, Juliette Danielle, Greg Sestero]
# 13     [Justin Chatwin, James Marsters, Chow Yun-Fat]
# 91               [JJ Feild, Leo Gregory, Kuno Becker]
# 90      [Nick Swardson, Don Johnson, Christina Ricci]
# 5     [Kirk Cameron, Darren Doane, Bridgette Cameron]
# 45    [Joey King, Julia Goldani Telles, Jaz Sinclair]
# 51     [Shaquille O'Neal, Annabeth Gish, Judd Nelson]
# 67  [Til Schweiger, Emmanuelle Vaugier, Natalia Av...

# %%
df.tail()
# Out:
#     rank                                           name  year certification  \
# 95    96                                  The Love Guru  2008         PG-13
# 96    97                             The Hungover Games  2014             R
# 97    98  In the Name of the King: A Dungeon Siege Tale  2007         PG-13
# 98    99                                   The Avengers  1998         PG-13
# 99   100             The Flintstones in Viva Rock Vegas  2000            PG
#
#    duration rating review_count               director  \
# 95   1h 27m    3.8          54K       [Marco Schnabel]
# 96   1h 25m    3.5          16K        [Josh Stolberg]
# 97    2h 7m    3.8          51K             [Uwe Boll]
# 98   1h 29m    3.8          45K  [Jeremiah S. Chechik]
# 99   1h 30m    3.7          25K         [Brian Levant]
#
#                                                writer  \
# 95                         [Mike Myers, Graham Gordy]
# 96  [Writers, Kyle Barnett Anderson, David Bernste...
# 97  [Writers, Doug Taylor, Jason Rappaport, Dan St...
# 98                    [Sydney Newman, Don MacPherson]
# 99  [Writers, William Hanna, Joseph Barbera, Debor...
#
#                            genre  \
# 95      [Comedy, Romance, Sport]
# 96  [Adventure, Comedy, Fantasy]
# 97  [Action, Adventure, Fantasy]
# 98   [Action, Adventure, Sci-Fi]
# 99     [Comedy, Family, Romance]
#
#                                              stars
# 95        [Mike Myers, Jessica Alba, Romany Malco]
# 96      [Ben Begley, Herbert Russell, Ross Nathan]
# 97        [Jason Statham, Ron Perlman, Ray Liotta]
# 98      [Ralph Fiennes, Uma Thurman, Sean Connery]
# 99  [Mark Addy, Stephen Baldwin, Kristen Johnston]

# %% [markdown]
# # SAVING THE DATASET

# %%
df.to_csv('lowest_ranked_movies_data.csv',index= False)
